# %% [markdown]
# # Ejercicios Matplotlib
#
#
# ## Datos de muestra

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123) # SEMILLA PARA nÚMEROS ALEATORIOS
x = np.arange(0,100)
y = x*2
z = x**2

# %%
# %matplotlib inline

# %% [markdown]
# ## Ejercicio 1
#
# Reproduce este dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

# Datos
x = [0, 100]
y = [0, 200]

# Crear el gráfico
plt.plot(x, y)

# Añadir etiquetas y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Ejercicio 1')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 2
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Datos
x = [0, 100]
y = [0, 200]

# Crear el gráfico principal
fig, ax = plt.subplots()
ax.plot(x, y, 'r')  # Línea roja
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Ejercicio 2')

# Crear el gráfico insertado
ax_inset = inset_axes(ax, width="20%", height="20%", loc='upper center')
ax_inset.plot(x, y, 'r')  # Línea roja
ax_inset.set_xlim(0, 100)
ax_inset.set_ylim(0, 200)
ax_inset.set_xticks([0, 20, 40, 60, 80, 100])
ax_inset.set_yticks([0, 50, 100, 150, 200])

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 3
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np

# Datos
x = np.linspace(0, 100)
y = np.exp(x / 100)

# Crear el gráfico principal
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel('X')
ax.set_ylabel('Z')
ax.set_title('Ejercicio 3')

# Crear el gráfico insertado
ax_inset = inset_axes(ax, width="30%", height="30%", loc='upper left')
ax_inset.plot(x, y)
ax_inset.set_xlim(20, 22)
ax_inset.set_ylim(30, 45)
ax_inset.set_xticks([20, 21, 22])
ax_inset.set_yticks([30, 35, 40, 45])

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 4
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para el gráfico azul
x1 = np.linspace(0, 100, 100)
y1 = 2 * x1

# Datos para el gráfico rojo
x2 = np.linspace(0, 100, 100)
y2 = np.exp(x2 / 10)

# Crear el gráfico azul
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 6))

ax1.plot(x1, y1, 'b--')  # Línea azul discontinua
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('Gráfico Azul')
ax1.set_xlim(0, 100)
ax1.set_ylim(0, 200)

# Crear el gráfico rojo
ax2.plot(x2, y2, 'r')  # Línea roja continua
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('Gráfico Rojo')
ax2.set_xlim(0, 100)
ax2.set_ylim(0, 10000)

# Mostrar los gráficos
plt.suptitle('Ejercicio 4')
plt.show()

# %% [markdown]
# ##Ejercicio 5
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para el gráfico azul
x1 = np.linspace(0, 100, 100)
y1 = 2 * x1

# Datos para el gráfico rojo
x2 = np.linspace(0, 100, 100)
z2 = np.exp(x2 / 10)

# Crear el gráfico azul
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(x1, y1, 'b')  # Línea azul continua
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_title('Gráfico Azul')
ax1.set_xlim(0, 100)
ax1.set_ylim(0, 200)

# Crear el gráfico rojo
ax2.plot(x2, z2, 'r--')  # Línea roja discontinua
ax2.set_xlabel('x')
ax2.set_ylabel('z')
ax2.set_title('Gráfico Rojo')
ax2.set_xlim(0, 100)
ax2.set_ylim(0, 10000)

# Mostrar los gráficos
plt.suptitle('Ejercicio 5')
plt.show()

# %% [markdown]
# ## Ejercicio 6
#
# Reproduce el siguiente dibujo a partir del código
#
# ```python
# # Ejes
# ax = plt.axes(projection='3d')
# # Línea
# zline = np.linspace(0, 15, 1000)
# xline = np.sin(zline)
# yline = np.cos(zline)
# # Nube de puntos
# zdata = 15 * np.random.random(100)
# xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
# ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Ejes
fig = plt.figure()
ax = plt.axes(projection='3d')

# Línea
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'blue')

# Nube de puntos
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Reds')

# Mostrar el gráfico
plt.show()
